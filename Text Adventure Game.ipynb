# %% [markdown]
# # Deal or No Deal with a TWIST!
#
# This is deal or no deal with a twist. You will have 3 levels to go through.
# The quest is to win the game by becoming a millionaire. Except this is deal or
# no deal with a twist. There is a surprise element in how you get to win one million USD
#
# Game Map:
# <br><br>
#
# ~~~
#     Level 1 --> Level 2 --> Level 3 (win)
#             |          |
#              `----------Bank deals`------> Stale Mate
# ~~~

# %% [markdown]
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />

# %%
"""Deal or no deal with a twist consists of 3 levels. Level 1 is about the end-user picking a case number at random and hoping that the case has enough money to get to the threshold of 150,000.00$ for the level. Level 2 introduces the banker who would make deals with the end-user, and this would be a general question quiz. 
    The objective is to get the threshold for the level of 350,000.00$, and not stale the game with the baker's deals. Level 3 introduces another twist, a lump sum of 600,000.00$ or risk it to lose it all!"""

def Level_1():
    """This function begins the game and gives instructions to the end-user about the game and level 1. The function is based on the randomization of cases. The function is void and does not return any value."""
    
    #Importing libraries needed for the level
    import random

    #Give user game introduction, and explain the logic and rules of the first stage.
    print(f"""You are on a quest to win a\033[1m million dollar\033[0m and this is your first step.\nDoes the banker does not want to deplete all the funds in the bank, \nhe/she may strike a deal with you to leave the lower lump sum than a million dollars. \nShould you take the deal, that is a stale game a win for the banker and one for you, \nelse continue playing and try your luck!\n""")
    
    #Variable decleration
    caseAmount = 0
    bank = 0
    roundMax = 150000
    choicesLst = []
    gameComplements = ["You are doing so well!", "Keep up the good work!", "You are amazing at this!", "Seems you are on your way to a million after all!"]
    tries = 0
    roundMaxTries = 3
    level1Threshold = 150000
    case1 = random.randint(0,150001)
    case2 = random.randint(0,150001)
    case3 = random.randint(0,150001)
    case4 = random.randint(0,150001)
    case5 = random.randint(0,150001)
    case6 = random.randint(0,150001)
    case7 = random.randint(0,150001)
    case8 = random.randint(0,150001)
    case9 = random.randint(0,150001)
    case10 = random.randint(0,150001)
    
    #Get user input to begin the game
    isBegin = False
    
    while isBegin == False:
        
        #Introduce Level
        print("""\n\033[4m\033[1mLeve 1!\033[0m\033[0m""")
        
        #Get user input and begin the game else quit the game
        begin = input(prompt="Are you ready to begin? (Y = yes / N = no / Q = quit): ")
    
        if begin.lower() == "y" or "ye" in begin.lower() or "yea" in begin.lower() or "yhea" in begin.lower() or "begin" in begin.lower() or "play" in begin.lower():
            
            #Set the begining of the game to true
            isBegin = True
            
        elif begin.lower() == "q" or "quit" in begin.lower() or "leave" in begin.lower():
            
            #Quit the game
            Quit()
            return
        
        else:
            
            #Call the not ready function and give the user time to get ready
            Not_Ready()
            
   #Start the game!
   #Additional informational to start of the game
    print(f"""\nYou have\033[1m 0$\033[0m in your bank right now, but don't worry, you are not walking away from this game empty-handed.\nYour threshold is\033[1m 150,000.00$\033[0m, you will lose the game if you get less than this in level 1. You have 3 tries in this round.\n""")
    
    #Count down to start game
    Start_Game_count()
    
    #Check whether the threshold is reached or the number of tries is depleted and continue randomizing the play.
    while bank < roundMax and tries < roundMaxTries:
        #Randomize the case
        randCase = input(prompt="Input a random number between 1 and 10 (Including 1 and 10), and press ''Enter''")

        try:
        
            #Register tries
            tries += 1
            
            #Check if the case or the choice has already been registered
            if randCase.lower() in choicesLst:
                print("""\n\033[35mTry again you have already opened this case.\033[0m\n""")
                
                #Make sure that the tries are reduced given that it was not a valid entry
                tries -= 1
                continue
                
            #Get the case and check the random random number in the case
            if str(randCase) == "1" or str(randCase.lower()) == "one": 
                
                print(f"""You have landed:\033[36m {case1}$ !!!\033[0m\n""")
                
                #Register the choices, each choice counts as two entries
                choicesLst.insert(0, "one")
                choicesLst.insert(0, "1")
                
                if case1 == roundMax:
                    bank = roundMax
                    
                    #Print and congratulate the user
                    print(f"""\nBam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[1m\033[92m{roundMax}$\033[0m\033[1m in your bank.\n""")
                    
                    #call the next level and promote the user
                    Level_2()
                    
                    #Exit the function once you have won
                    return

                else:
                    bank += case1
                    print(f"""The total amount in your bank is:\033[1m {bank}$\033[0m""")
                    
                     #Check if the level is complete
                    if bank >= roundMax:
                        
                        print(f"""\nBam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{roundMax}$\033[0m in your bank.\n""")
                    
                        #call the next level and promote the user
                        Level_2()
                        
                        #Exit the function once you have won
                        return

            elif str(randCase) == "2" or str(randCase.lower()) == "two":
                
                print(f"""You have landed:\033[36m {case2}$ !!!\033[0m""")
                
                #Register the choices, each choice counts as two entries
                choicesLst.insert(0, "two")
                choicesLst.insert(0, "2")

                if case2 == roundMax:                    
                    bank = roundMax
                    
                    print(f"""Bam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{roundMax}$\033[0m in your bank.""")
                    
                    #call the next level and promote the user
                    Level_2()
                    
                    #Exit the function once you have won
                    return
                    
                else:
                    #Aggregate to the bank and print amount
                    bank += case2
                    print(f"""The total amount in your bank is:\033[1m {bank}$\033[0m""")
                    
                    #Check if the level is complete
                    if bank >= roundMax:
                        
                        print(f"""\nBam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{roundMax}$\033[0m in your bank.\n""")
                    
                        #call the next level and promote the user
                        Level_2()
                        
                        #Exit the function once you have won
                        return
                    
            elif str(randCase) == "3" or str(randCase.lower()) == "three":
                
                print(f"""You have landed:\033[36m {case3}$\033[0m !!!\033[0m""")
                
                #Register the choices, each choice counts as two entries
                choicesLst.insert(0, "three")
                choicesLst.insert(0, "3")

                if case3 == roundMax:
                    bank = roundMax
                    
                    print(f"""\nBam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: {roundMax}$ in your bank.\n""")
                    
                    #call the next level and promote the user
                    Level_2()
                    
                    #Exit the function once you have won
                    return
                    
                else:
                    bank += case3
                    print(f"""The total amount in your bank is:\033[1m {bank}$\033[0m""")
                    
                    #Check if the level is complete
                    if bank >= roundMax:
                        
                        print(f"""\nBam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{roundMax}$\033[0m in your bank.\n""")
                    
                        #call the next level and promote the user
                        Level_2()
                        
                        #Exit the function once you have won
                        return
                    
            elif str(randCase) == "4" or str(randCase.lower()) == "four":
                
                print(f"""You have landed:\033[36m {case4}$ !!!\033[0m""")
                
                 #Register the choices, each choice counts as two entries
                choicesLst.insert(0, "four")
                choicesLst.insert(0, "4")

                if case4 == roundMax:
                    bank = roundMax
                    
                    print(f"""Bam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{roundMax}$\033[0m in your bank.""")
                    
                    #call the next level and promote the user
                    Level_2()
                    
                    #Exit the function once you have won
                    return
                    
                else:
                    bank += case4
                    
                    print(f"""The total amount in your bank is:\033[1m {bank}$\033[0m""")
                    
                    #Check if the level is complete
                    if bank >= roundMax:
                        
                        print(f"""\nBam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{roundMax}$\033[0m in your bank.\n""")
                    
                        #call the next level and promote the user
                        Level_2()
                        
                        #Exit the function once you have won
                        return

            elif str(randCase) == "5" or str(randCase.lower()) == "five":
                
                print(f"""You have landed:\033[36m {case5}$ !!!\033[0m""")
                
                #Register the choices, each choice counts as two entries
                choicesLst.insert(0, "five")
                choicesLst.insert(0, "5")

                if case5 == roundMax:
                    bank = roundMax
                    
                    print(f"""Bam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: {roundMax}$ in your bank.""")
                    
                    #call the next level and promote the user
                    Level_2()
                    
                    #Exit the function once you have won
                    return
                    
                else:
                    bank  += case5
                    print(f"""The total amount in your bank is:\033[1m {bank}$\033[0m""")
                    
                    #Check if the level is complete
                    if bank >= roundMax:
                        
                        print(f"""\nBam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{roundMax}$\033[0m in your bank.\n""")
                    
                        #call the next level and promote the user
                        Level_2()
                        
                        #Exit the function once you have won
                        return
                    
            elif str(randCase) == "6" or str(randCase.lower()) == "six":
                
                print(f"""You have landed:\033[36m {case6}$ !!!\033[0m""")
                
                #Register the choices, each choice counts as two entries
                choicesLst.insert(0, "six")
                choicesLst.insert(0, "6")

                if case6 == roundMax:
                    bank  = roundMax
                    
                    print(f"""Bam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{roundMax}$\033[0m in your bank.""")
                    
                    #call the next level and promote the user
                    level_2()
                    
                    #Exit the function once you have won
                    return
                    
                else:
                    bank += case6
                    print(f"""The total amount in your bank is:\033[36m {bank}$\033[0m""")
                    
                    #Check if the level is complete
                    if bank >= roundMax:
                        
                        print(f"""\nBam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{roundMax}$\033[0m in your bank.\n""")
                    
                        #call the next level and promote the user
                        Level_2()
                        
                        #Exit the function once you have won
                        return

            elif str(randCase) == "7" or str(randCase.lower()) == "seven":
                
                print(f"""You have landed:\033[36m {case7}$ !!!\033[0m""")
                
                #Register the choices, each choice counts as two entries
                choicesLst.insert(0, "seven")
                choicesLst.insert(0, "7")

                if case7 == roundMax:
                    bank  = roundMax
                    
                    print(f"""Bam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{roundMax}$\033[0m in your bank.""")
                    
                    #call the next level and promote the user
                    Level_2()
                    
                    #Exit the function once you have won
                    return
                    
                else:
                    bank += case7
                    print(f"""The total amount in your bank is:\033[1m {bank}$\033[0m""")
                    
                    #Check if the level is complete
                    if bank >= roundMax:
                        
                        print(f"""\nBam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{roundMax}$\033[0m in your bank.\n""")
                    
                        #call the next level and promote the user
                        level_2()
                        
                        #Exit the function once you have won
                        return

            elif str(randCase) == "8" or str(randCase.lower()) == "eight":
                
                print(f"""You have landed:\033[36m {case8}$ !!!\033[0m""")
                
                #Register the choices, each choice counts as two entries
                choicesLst.insert(0, "eight")
                choicesLst.insert(0, "8")

                if case8 == roundMax:
                    bank = roundMax
                    
                    print(f"""Bam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{roundMax}$\033[0m in your bank.""")
                    
                    #call the next level and promote the user
                    Level_2()
                    
                    #Exit the function once you have won
                    return
                
                else:
                    bank += case8
                    print(f"""The total amount in your bank is:\033[1m {bank}$\033[0m""")
                    
                    #Check if the level is complete
                    if bank >= roundMax:
                        
                        print(f"""\nBam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{roundMax}$\033[0m in your bank.\n""")
                    
                        #call the next level and promote the user
                        Level_2()
                        
                        #Exit the function once you have won
                        return

            elif str(randCase) == "9" or str(randCase.lower()) == "nine":
                
                print(f"""You have landed:\033[36m {case9}$ !!!\033[0m""")
                
                #Register the choices, each choice counts as two entries
                choicesLst.insert(0, "nine")
                choicesLst.insert(0, "9")

                if case9 == roundMax:
                    bank = roundMax
                    
                    print(f"""Bam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{roundMax}$\033[0m in your bank.""")
                    
                    #call the next level and promote the user
                    Level_2()
                    
                    #Exit the function once you have won
                    return
                
                else:
                    bank += case9
                    print(f"""The total amount in your bank is:\033[1m {bank}$\033[0m""")
                    
                    #Check if the level is complete
                    if bank >= roundMax:
                        
                        print(f"""\nBam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{roundMax}$\033[0m in your bank.\n""")
                    
                        #call the next level and promote the user
                        Level_2()
                        
                        #Exit the function once you have won
                        return

            elif str(randCase) == "10" or str(randCase.lower()) == "ten":
                
                print(f"""You have landed:\033[36m {case10}$ !!!\033[0m""")
                
                #Register the choices, each choice counts as two entries
                choicesLst.insert(0, "ten")
                choicesLst.insert(0, "10")

                if case10 == roundMax:
                    bank = roundMax
                    
                    print(f"""Bam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{roundMax}$\033[0m in your bank.""")
                    
                    #call the next level and promote the user
                    Level_2()
                    
                    #Exit the function once you have won
                    return
                
                else:
                    bank += case10
                    print(f"""The total amount in your bank is:\033[1m {bank}$\033[0m""")
                    
                    #Check if the level is complete
                    if bank >= roundMax:
                        
                        print(f"""\nBam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{roundMax}$\033[0m in your bank.\n""")
                    
                        #call the next level and promote the user
                        Level_2()
                        
                        #Exit the function once you have won
                        return
            else:
                #Reduce the tries given that that was not a valid entry:
                tries -= 1
                print("You may have not selected the correct option, please check again!")            
            
        except Exception as e:
            #Reduce the tries given that that was not a valid entry:
            tries -= 1
            print("Please make sure that you have entered a valid number like: 1 or 9")
            #print("Exception: ", e)

        else:

          #randomize the complement
          print(f"""{gameComplements[random.randint(0,3)]}""")  

    #print(f"""You have exhausted all your tries for the first stage!""")
    
    #Check if game over
    if bank < level1Threshold:
        
        #print("""\033[1mGame over!\033[0m\nYou have not reached the threshold of level 1""") 
        
        #Game is over for this level
        GameOver()
        
        #Restart the game where possible
        playAgain = input(prompt="\nWould you like to play again? (Y = yes / N = no)")
        
        try:
            if playAgain.lower() == "y" or "ye" in playAgain.lower() or "yea" in playAgain.lower() or "yhea" in playAgain.lower() or "again" in playAgain.lower() or "play" in playAgain.lower():
            
                #reset all variables and start again
                bank = 0
                tries = 0
                
                #Trigger a replay for the end-user
                Quit() 
            else:
                #Print nothing
                print("")
            
        except Exception as e:
            
            #print("E: ",e,"\n")
            
            #Print a user-friendly message to the user when something has gone wrong
            print("Please make sure that you have entered the correct input.")
            
    else:
        print("")
               
def Level_2():
    """This function begins level 2, the function has a twist to deal or no deal by introducing a general question quiz. The function is void and does not return any value."""
 
    #Importing libraries needed for the level   
    import random
    
    #Variable declaration
    questionsLst = [["Who is Nintendo's most widely recognized mascot?","Steve","Bowser","Mario"],["Which month of the year has 28 days in?","February","All","December"],["How many holes are on a standard bowling ball?","2","7","3"],["Which is the country with the biggest population in Europe?","Germany","Russia","France"],["What are made and repaired by a cobbler?","Keys","Shoes","Furniture"],["What is the national animal of Pakistan?","Peacock","Markhor","Lion"],["How many rings are on the Olympic flag?","4","7","5"]]
    answerLst = [[0,3,"Mario"],[1,2,"All"],[2,3,"3"],[3,2,"Russia"],[4,2,"Shoes"],[5,2,"Markhor"],[6,3,"5"]]
    randomQuestions = random.randint(0,len(questionsLst))
    keepRandomQustions = [] 
    maxQ = 5
    qCount = 0
    bank = 0
    correctAnswerAmount = 70000
    maxAmount = 350000
    
    try:
        #Introduction to level 2 with formatting and styling.
        print("""\n\033[4m\033[1mLeve 2!\033[0m\033[0m""")
        print("""\nThe \x1B[3mbanker\x1B[0m is getting worried about liquidity in the bank, he may once in a while strike a deal with you.\nYou have 5 tries before the game ends.\nThe threshold for this level is \033[1m350,000.00$\033[0m""")
        print("""You must get \033[1m350,000.00$\033[0m before you run out of tries to get promoted to the next level.\n\nStarting in: \n""")

        #Count down before the next level
        SecCountDown()

        #Display the Twist
        print("""\nHere is a twist:\nYou will have to answer a couple of general questions.""")

        #Ask the question
        while qCount < maxQ:
                        
            #Make sure that you are not asking the same question
            while randomQuestions in keepRandomQustions:
                randomQuestions = random.randint(0,len(questionsLst)-1)
                #keepRandomQustions.insert(0, randomQuestions)

            #Ask the randomized question and print the multiple choice
            print(f"""\n{questionsLst[randomQuestions][0]}""")

            #Multiple choice
            counter = 0 # Counter to count the multiple choice
            for i in questionsLst[randomQuestions]:
                
                #make sure that you don't ask the question more than once
                if counter > 0:
                    print(f"""{counter}) {i}""")
                else:
                    print("")
                    
                #Increasing the sentinel for the multiple choice question
                counter += 1
            
            #Get the user answer:
            answer = input(prompt="Enter the number that corresponds to the correct answer. (Like 1 or 2): ")
            
            qCount += 1 #Increase the counter to register the question has been asked
            
            #Give the user an answer
            if str(answer) == str(answerLst[randomQuestions][1]) or str(answer.lower()) in (answerLst[randomQuestions][2]).lower():
                
                print("You are correct, that is the correct answer!")
                
                #Aggregate to the bank
                bank += correctAnswerAmount
                
                print(f"""You have \033[1m{bank}$\033[0m in your bank!""")
                
                #Check if we have finished the level and call the next level
                if bank >= maxAmount:
                    print(f"""\nBam! You are getting elevated unto the next level now! \nCongratulations you are on your way to a million. You have now won: \033[92m{maxAmount}$\033[0m in your bank.\n""")
                    
                    #Promomote to the next level
                    Level_3()
                    
                    #Complete the level
                    return
                    
                #Banker strikes a deal
                BankerDeal()
                
                #Confirm continue the game
                continueGame = input(prompt="Would you like to take the offer? (Y = yes / N = no): ")
                
                #Confirm whether player would like to continue playing or not
                if continueGame.lower() == "y" or continueGame.lower() == "yes" or "yhea" in continueGame.lower() or "ok" in continueGame.lower() or "okay" in continueGame.lower():
                    
                    #Quit the game and end
                    DealAccpet()
                    
                    #End the game
                    return                    
                    
                else:
                    
                    print(f"""\nOkay let's keep playing.\nYou have \033[1m{bank}$\033[0m in the bank!\n""")
                    
                    #Lose the game if the threshold is not reached and the number of tries have depleted
                    if maxQ == qCount and  bank < maxAmount:
                        
                        print("""\nYou have unfortunately run out of tries!\n\n""")
                        
                        #Call Game over
                        GameOver()
            else:
                #Make sure that the number of tries left is valid and that the user is still in the game
                if (qCount+1) == maxQ and bank < maxAmount:
                    
                    GameOver() #Call the game over if the user has exceeded the tries and the bank amount is less than that of the level
                    
                else:
                    print(f"""Aaaah your answer was not correct. You have {maxQ-qCount} tries left.\n""")
                    
                    #You do not have any tries left and you just got the wrong answer
                    if maxQ-qCount == 0:
                        #Call Game Over
                        GameOver()                     
                            
            #Register the question to not repeat
            keepRandomQustions.insert(0, randomQuestions)
            
            #Randomize your next question
            randomQuestions = random.randint(0,len(questionsLst)-1)
            
    except Exception as e:
        
        #Print a user friendly error message
        print("""Something went wrong, please contact the administrator.""")
        #print("Exception: ", e)
    
    return

def Level_3():
    """This function begins level 3 to the game, it is responsible for an added twist to deal or no deal, which wins the game at one go or stale sets the game to stale. This is a void function and does not return any value."""
    #Importing libraries needed for the level
    import random

    #Introduction to level 3 with formatting and styling.
    
    try:
        
        rand = random.randint(0, 15) #Get random case with the 500,000$
        
        print("""\n\033[4m\033[1mLeve 3!\033[0m\033[0m""")
        print("""\nHey, it's the banker here. I am beginning to really believe you are good at this.\nOn this level, you can win the remainder of \033[1m500,000.00$!\033[0m.\nI have two options for you, trust me it's getting harder now.\n1) Take 20% off of this level and go home safely with \033[1m600,000.00$\033[0m in cash!\n2) Take a chance and risk it all. You have 1 try to get the \033[1m500,000.00$\033[0m and you could walk away with \033[1m1000,000.00$\033[0m in cash.\n\n""")
        
        answer = input(prompt="Choose the game you would like to play, 1 or 2?: ")
        
        #Make sure that the end-user enters the correct number
        while str(answer) != "1" and "off" not in answer.lower() and "600" not in answer.lower() and "one" not in answer.lower() and str(answer) != "2" and "risk" not in answer.lower() and "two" not in answer.lower():
            answer = input(prompt="Choose the game you would like to play, 1 or 2?: ")
        
        #Check if the answer is correct and decide on the option to play.
        if str(answer) == "1" or "off" in answer.lower() or "600" in answer.lower() or "one" in answer.lower(): #Game option 1
            
            #Game win and end game with return
            GameWinOption1()
            return
        
        elif str(answer) == "2" or "risk" in answer.lower() or "two" in answer.lower(): #Game option 2
            
            number = input(prompt="Enter a number between 1 to 15: ")
        
        #Confirm that the random number and the one entered are equal the same to win the game otherwise
        if str(rand) == str(number):
            
            #Game win option 2 and end game with return
            GameWinOption2()
            
            return
        else:
            
            #The guess was not correct
            print("\nYou did \033[1mnot\033[0m guess the correct case number\n\n")
            
            #Game Over and end game with return
            GameOver()
            
            return
    
    except Exception as e:
        print("Something went wrong, please contact the administrator.") #Return a friendly exception
        #print("Exception: ", e)
    
def Not_Ready():
    """This function prints a ready print to the end-user, and calls a 5-second count down to start the game when the end-user was not ready."""
    
    #Well maybe the enduser has made a mistake or does not want to play right away
    #Give the user 5 seconds until then
    print("\nHhmm... Okay let me give you 5 seconds to make up your mind.")
    
    #Call the 5 seconds count down
    SecCountDown()
        
def SecCountDown():
    """The function is responsible to count down from 5 seconds down. This is a void function and does not return any value."""
    #Importing libraries needed for the level
    import time
    
    sec = 5
    
    #Sleep for a second in the loop to wait for 5 seconds
    while sec > 0:
        print(f"""{sec}...""")
        sec -=1
        time.sleep(1)
        
def Quit():
    """This function prints the good bey message to the end-user. The function is void and does not return any value."""
    
    #Print the good bey message
    print("""\nYou have decided to quit the game and take home what you have earned, and that could be nothing. \n\nThank you and please come again soon!\n""")
    
    #Make it possible for the user to play again
    input(prompt="\nPress any key if you would like to play again.\n")
    
    #start the game over
    Level_1()

def GameOver():
    """This is a game over function that prints "game over" to the end-user when it is called. The function is void and does not return any value, but prints text."""
    
    #Print game over text
    print("""   _____                         ____                              
  / ____|                       / __ \                             
 | |  __  __ _ _ __ ___   ___  | |  | |_   _____ _ __              
 | | |_ |/ _` | '_ ` _ \ / _ \ | |  | \ \ / / _ \ '__|             
 | |__| | (_| | | | | | |  __/ | |__| |\ V /  __/ |     _   _   _  
  \_____|\__,_|_| |_| |_|\___|  \____/  \_/ \___|_|    (_) (_) (_) """)
    
    print(""" __     __           _                  _ 
 \ \   / /          | |                | |
  \ \_/ /__  _   _  | | ___  ___  ___  | |
   \   / _ \| | | | | |/ _ \/ __|/ _ \ | |
    | | (_) | |_| | | | (_) \__ \  __/ |_|
    |_|\___/ \__,_| |_|\___/|___/\___| (_) """)
    
    #Make it possible for the user to play again
    input(prompt="\nPress any key if you would like to play again.")
    
    #start the game over
    Level_1()

def GameWinOption1():
    """This function prints the winning text to the end-user. In addition to winning the function prints, the lump sum won. This is a void function and does not return anything."""

    #Print end Game results
    print("""\nYou have won a whopping: \33[1m600,000.00$\33[0m \n""")
    
    #Call the stale mate
    DealAccpet()
    
def GameWinOption2():   
    """The function prints the winning text for the end-user. In addition to the winning text, the function prints the lump sum won. This is a void function and does not return value."""
    
    #Print the prize
    print("\nYou have won a whopping \33[1m1000,000.00$\33[0m congratulations!!\n")
    
    #Print end Game results
    print("""
 \ \        / (_)                       | |
  \ \  /\  / / _ _ __  _ __   ___ _ __  | |
   \ \/  \/ / | | '_ \| '_ \ / _ \ '__| | |
    \  /\  /  | | | | | | | |  __/ |    |_|
     \/  \/   |_|_| |_|_| |_|\___|_|    (_) """)
    
def DealAccpet():   
    """This function prints the stale mate and does not return any value."""
    
    #Print Information
    print("\nYou have accepted the banker's deal, and taken your lump sum. You did \033[1mnot\033[0m win the game.")
    
    #Print end Game results
    print("""     _        _    _    
  / ____| |      | |      |  \/  |     | |       | |
 | (___ | |_ __ _| | ___  | \  / | __ _| |_ ___  | |
  \___ \| __/ _` | |/ _ \ | |\/| |/ _` | __/ _ \ | |
  ____) | || (_| | |  __/ | |  | | (_| | ||  __/ |_|
 |_____/ \__\__,_|_|\___| |_|  |_|\__,_|\__\___| (_)""")
        
def BankerDeal():
    """The function randomizes the banker's deal to the end-user. This is a void function and does not return anything."""
    #Importing libraries 
    import random
    
    #Set the random Questions to make a deal with the player
    dealQs = ["Be careful you could lose your entire bank lump sum, go home with what you have now, and save the day!","Would you like to leave with what you got now, think about what you could do with all this money?","You have such an amount now, consider taking this home, and making the best out of it.", "I will be straight and forward: Quit now and thank me later!!"]
    
    #print the random question to make a deal with the player
    print(f"""\nHey! It's the banker here. I would like to strike a deal with you.\n{dealQs[random.randint(0,len(dealQs)-1)]}""")
    
def Start_Game_count():
    """This is a start function, starts the game with a count down from 5 seconds. The function is void and does not return any value."""
    import time # Import time library to start the count down to the game start
    
    print("""\n\033[92mStarting game in...\n\033[0m""") #Print count down
    
    time.sleep(1) 
    sec = 5
    
    while sec > 0: #Count the game down in 5 seconds.
        
        print(f"""{sec}...""")
        sec -= 1
        time.sleep(1)
    
Level_1() # This starts the game
# Out:
# You are on a quest to win a million dollar and this is your first step.
# Does the banker does not want to deplete all the funds in the bank,
# he/she may strike a deal with you to leave the lower lump sum than a million dollars.
# Should you take the deal, that is a stale game a win for the banker and one for you,
# else continue playing and try your luck!
#
#
# Leve 1!
# Are you ready to begin? (Y = yes / N = no / Q = quit): y
#
# You have 0$ in your bank right now, but don't worry, you are not walking away from this game empty-handed.
# Your threshold is 150,000.00$, you will lose the game if you get less than this in level 1. You have 3 tries in this round.
#
#
# Starting game in...
#
# 5...
# 4...
# 3...
# 2...
# 1...
# Input a random number between 1 and 10 (Including 1 and 10), and press ''Enter''2
# You have landed: 54384$ !!!
# The total amount in your bank is: 54384$
# Keep up the good work!
# ...

# %% [markdown]
# <br>
